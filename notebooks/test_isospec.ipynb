# %%
import IsoSpecPy

# %%
# Composition alone (element -> atom count), no envelope --
# this is what R's RParsePeptideSequence returns.
composition = IsoSpecPy.ParsePeptideSequence("AB[UNIMOD:42]C")
print(dict(composition))
# Out:
# {'H': 22, 'C': 14, 'N': 2, 'O': 3, 'S': 3}

# %%
env = IsoSpecPy.IsoTotalProb(prob_to_cover=0.999, peptide_sequence="AB[UNIMOD:42]C")

# %%
masses = env.np_masses()
print(masses)
# Out:
# [362.0792561  363.076291   364.07505196 363.07864384 363.08261094
#  365.07840679 364.08596577 364.08350109 363.08347324 363.08553285
#  366.07929695 365.07926909 365.0813287  365.07208685 365.08288883
#  365.08932061 364.07567873 366.07084781 365.07443969 366.07426613
#  364.07803157 365.08535351 366.08176163 365.08685593 364.08682807
#  364.08888768 364.07964583 366.07779453 367.07420265 366.07544169
#  364.08199867 367.08265179]

# %%
probs = env.np_probs()
print(probs)
# Out:
# [7.23716126e-01 5.29079618e-03 9.71927431e-02 1.71876923e-02
#  1.10496930e-01 1.48393816e-02 7.83280831e-03 4.46473595e-03
#  8.29221213e-04 1.84251683e-03 5.99599647e-04 1.11361736e-04
#  2.47444071e-04 7.10536874e-04 1.06033989e-04 3.41689331e-04
#  1.25652274e-04 4.35089071e-03 1.53883445e-03 2.51415712e-04
#  1.36064753e-04 1.86023075e-04 1.05192091e-03 6.81675590e-04
#  1.26605440e-04 2.81315348e-04 8.07798412e-04 2.34949143e-04
#  6.64293707e-04 1.08484723e-04 2.62421573e-03 9.15468346e-05]
